# %%
import pandas as pd

# %%
df=pd.read_csv("bangalore_qcommerce_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 947752 entries, 0 to 947751
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Order_ID                 947752 non-null  int64
#  1   Company                  947752 non-null  object
#  2   City                     947752 non-null  object
#  3   Customer_Age             947752 non-null  int64
#  4   Order_Value              947752 non-null  int64
#  5   Delivery_Time_Min        947752 non-null  int64
#  6   Distance_Km              947752 non-null  float64
#  7   Items_Count              947752 non-null  int64
#  8   Product_Category         947752 non-null  object
#  9   Payment_Method           947752 non-null  object
#  10  Customer_Rating          947752 non-null  int64
#  11  Discount_Applied         947752 non-null  int64
#  12  Delivery_Partner_Rating  947752 non-null  int64
# dtypes: float64(1), int64(8), object(4)
# ...

# %%
df.head()
# Out:
#    Order_ID           Company          City  Customer_Age  Order_Value  \
# 0   1000001  Swiggy Instamart  Banashankari            46          702
# 1   1000002  Flipkart Minutes  Marathahalli            56         1007
# 2   1000003  Flipkart Minutes   Koramangala            18         1212
# 3   1000004  Swiggy Instamart   Rajajinagar            23         1179
# 4   1000005             Dunzo    BTM Layout            44          586
#
#    Delivery_Time_Min  Distance_Km  Items_Count Product_Category  \
# 0                 19         12.0           12            Dairy
# 1                 20         12.7           10           Snacks
# 2                 17          4.8           19    Personal Care
# 3                  6          6.4            2            Dairy
# 4                 12          2.4           13        Household
#
#      Payment_Method  Customer_Rating  Discount_Applied  \
# 0            Wallet                2                 1
# ...

# %%
df.describe()
# Out:
#            Order_ID   Customer_Age    Order_Value  Delivery_Time_Min  \
# count  9.477520e+05  947752.000000  947752.000000      947752.000000
# mean   1.500028e+06      38.471165     570.912008          16.506620
# std    2.887273e+05      12.118982     374.175332           6.340851
# min    1.000001e+06      18.000000      50.000000           5.000000
# 25%    1.249939e+06      28.000000     288.000000          12.000000
# 50%    1.500026e+06      38.000000     532.000000          16.000000
# 75%    1.750145e+06      49.000000     797.000000          20.000000
# max    2.000000e+06      59.000000    2492.000000          40.000000
#
#          Distance_Km    Items_Count  Customer_Rating  Discount_Applied  \
# count  947752.000000  947752.000000    947752.000000     947752.000000
# mean        7.750048      10.313292         3.042655          0.400786
# std         4.187153       5.630770         1.202499          0.490058
# ...

# %%
df.drop_duplicates()
# Out:
#         Order_ID           Company          City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart  Banashankari            46          702
# 1        1000002  Flipkart Minutes  Marathahalli            56         1007
# 2        1000003  Flipkart Minutes   Koramangala            18         1212
# 3        1000004  Swiggy Instamart   Rajajinagar            23         1179
# 4        1000005             Dunzo    BTM Layout            44          586
# ...          ...               ...           ...           ...          ...
# 947747   1999996        Big Basket   Rajajinagar            48           72
# 947748   1999997  Swiggy Instamart    Whitefield            33         1510
# 947749   1999998          Jio Mart    HSR Layout            29          637
# 947750   1999999             Dunzo    BTM Layout            42         1103
# 947751   2000000        Amazon Now     Yelahanka            19          759
#
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Company                    0
# City                       0
# Customer_Age               0
# Order_Value                0
# Delivery_Time_Min          0
# Distance_Km                0
# Items_Count                0
# Product_Category           0
# Payment_Method             0
# Customer_Rating            0
# Discount_Applied           0
# Delivery_Partner_Rating    0
# dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Banashankari', 'Marathahalli', 'Koramangala', 'Rajajinagar',
#        'BTM Layout', 'Whitefield', 'HSR Layout', 'Electronic City',
#        'Yelahanka', 'KR Puram', 'Sarjapur', 'Indiranagar', 'Jayanagar',
#        'Bellandur', 'Hebbal'], dtype=object)

# %%
dp=pd.read_csv("qcom_time.csv")

# %%
dp['Order_Date']=pd.to_datetime(dp['Order_Date'])

# %%
df.dtypes
# Out:
# Order_ID                     int64
# Company                     object
# City                        object
# Customer_Age                 int64
# Order_Value                  int64
# Delivery_Time_Min            int64
# Distance_Km                float64
# Items_Count                  int64
# Product_Category            object
# Payment_Method              object
# Customer_Rating              int64
# Discount_Applied             int64
# Delivery_Partner_Rating      int64
# dtype: object

# %%
dp.dtypes
# Out:
# Order_ID                int64
# Customer_ID            object
# Order_Date     datetime64[ns]
# Order_Time     datetime64[ns]
# dtype: object

# %%
df=df[df['Delivery_Time_Min']>0]

# %%
df['Company'].unique()
# Out:
# array(['Swiggy Instamart', 'Flipkart Minutes', 'Dunzo', 'Jio Mart',
#        'Blinkit', 'Amazon Now', 'Big Basket', 'Zepto'], dtype=object)

# %%
dq=pd.read_csv("bangalore_dark_store_dataset.csv")

# %%
dq.describe()
# Out:
#        No_of_Dark_Stores
# count          60.000000
# mean            3.500000
# std             2.095192
# min             1.000000
# 25%             2.000000
# 50%             3.000000
# 75%             4.250000
# max             8.000000

# %%
dq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area               60 non-null     object
#  1   App                60 non-null     object
#  2   No_of_Dark_Stores  60 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.5+ KB

# %%
dq.head()
# Out:
#           Area               App  No_of_Dark_Stores
# 0  Indiranagar             Zepto                  6
# 1  Indiranagar           Blinkit                  4
# 2  Indiranagar  Swiggy Instamart                  8
# 3  Indiranagar             Dunzo                  7
# 4   Whitefield             Zepto                  7

# %%
dq['Area'].unique()
# Out:
# array(['Indiranagar', 'Whitefield', 'Koramangala', 'Electronic City',
#        'Marathahalli', 'HSR Layout', 'BTM Layout', 'Yelahanka',
#        'Jayanagar', 'Rajajinagar', 'Bellandur', 'Sarjapur', 'Hebbal',
#        'Banashankari', 'KR Puram'], dtype=object)

# %%
dq.drop_duplicates()
# Out:
#                Area               App  No_of_Dark_Stores
# 0       Indiranagar             Zepto                  6
# 1       Indiranagar           Blinkit                  4
# 2       Indiranagar  Swiggy Instamart                  8
# 3       Indiranagar             Dunzo                  7
# 4        Whitefield             Zepto                  7
# 5        Whitefield           Blinkit                  4
# 6        Whitefield  Swiggy Instamart                  7
# 7        Whitefield             Dunzo                  5
# 8       Koramangala             Zepto                  6
# 9       Koramangala           Blinkit                  4
# 10      Koramangala  Swiggy Instamart                  4
# 11      Koramangala             Dunzo                  8
# 12  Electronic City             Zepto                  4
# 13  Electronic City           Blinkit                  3
# 14  Electronic City  Swiggy Instamart                  3
# ...

# %%
dq.isnull()
# Out:
#      Area    App  No_of_Dark_Stores
# 0   False  False              False
# 1   False  False              False
# 2   False  False              False
# 3   False  False              False
# 4   False  False              False
# 5   False  False              False
# 6   False  False              False
# 7   False  False              False
# 8   False  False              False
# 9   False  False              False
# 10  False  False              False
# 11  False  False              False
# 12  False  False              False
# 13  False  False              False
# 14  False  False              False
# 15  False  False              False
# 16  False  False              False
# 17  False  False              False
# 18  False  False              False
# 19  False  False              False
# 20  False  False              False
# 21  False  False              False
# 22  False  False              False
# 23  False  False              False
# 24  False  False              False
# ...

# %%
dq.dtypes
# Out:
# Area                 object
# App                  object
# No_of_Dark_Stores     int64
# dtype: object

# %%
df.to_csv("cleaned_bangalore_qcommerce_dataset.csv")

# %%
dq.to_csv("cleaned_bangalore_dark_store.csv")

# %%
dp.to_csv("cleaned_qcom_time.csv")

# %%
dp
